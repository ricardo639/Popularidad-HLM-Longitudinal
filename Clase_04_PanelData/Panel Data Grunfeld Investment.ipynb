# %% [markdown]
# # Ejemplo de Estimación por Datos Panel

# %% [markdown]
# Referencia: Vella and M. Verbeek (1998), “Whose Wages Do Unions Raise? A Dynamic Model of Unionism and Wage Rate Determination for Young Men,” Journal of Applied Econometrics 13, 163-183.

# %% [markdown]
# ## 1. Dependencias

# %%
#!pip install linearmodels==4.24
#!pip install linearmodels==4.5
# !pip install linearmodels
# Out:
# Collecting linearmodels
#   Downloading linearmodels-6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (0.14.4)
# Collecting mypy-extensions>=0.4 (from linearmodels)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from linearmodels) (3.0.12)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.0.0 (from linearmodels)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting setuptools-scm<9.0.0,>=8.0.0 (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels)
#   Downloading setuptools_scm-8.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.0->linearmodels)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->linearmodels) (2025.1)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.2)
# Requirement already satisfied: setuptools>=61 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (75.1.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.0->linearmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->linearmodels) (1.17.0)
# Downloading linearmodels-6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.6 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 7.3 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading setuptools_scm-8.2.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.1 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: setuptools-scm, mypy-extensions, interface-meta, pyhdfe, formulaic, linearmodels
# Successfully installed formulaic-1.1.1 interface-meta-1.3.0 linearmodels-6.1 mypy-extensions-1.0.0 pyhdfe-0.2.0 setuptools-scm-8.2.0

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col
from linearmodels.panel.model import PooledOLS, PanelOLS
from linearmodels.panel import RandomEffects
from linearmodels.panel import compare # Para comparar modelos

#
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Importación de datos

# %%
# Importamos el Data Set
data_to_load = 'wage_panel.csv'

# Read the and
wage_df = pd.read_csv(data_to_load)
wage_df.head()
# Out:
#    nr  year  black  exper  hisp  hours  married  educ  union     lwage  \
# 0  13  1980      0      1     0   2672        0    14      0  1.197540
# 1  13  1981      0      2     0   2320        0    14      1  1.853060
# 2  13  1982      0      3     0   2940        0    14      0  1.344462
# 3  13  1983      0      4     0   2960        0    14      0  1.433213
# 4  13  1984      0      5     0   3071        0    14      0  1.568125
#
#    expersq  occupation
# 0        1           9
# 1        4           9
# 2        9           9
# 3       16           9
# 4       25           5

# %% [markdown]
# ### Los datos importados son:
# * nr: person identifier
# * year: 1980 to 1987
# * black: =1 if black
# * exper: labor market experience
# * hisp: =1 if Hispanic
# * hours: annual hours worked
# * married: =1 if married
# * educ: years of schooling
# * union: =1 if in union
# * lwage: log(wage)
# * expersq: exper^2
# * occupation: Occupation code

# %%
# Adecuaciones al índice para hacerlo Panel:
year = wage_df.year
wage_df = wage_df.set_index(['nr', 'year'])
wage_df#.head()
#indice para indicar la combinacion del panel
# Out:
#             black  exper  hisp  hours  married  educ  union     lwage  \
# nr    year
# 13    1980      0      1     0   2672        0    14      0  1.197540
#       1981      0      2     0   2320        0    14      1  1.853060
#       1982      0      3     0   2940        0    14      0  1.344462
#       1983      0      4     0   2960        0    14      0  1.433213
#       1984      0      5     0   3071        0    14      0  1.568125
# ...           ...    ...   ...    ...      ...   ...    ...       ...
# 12548 1983      0      8     0   2080        1     9      0  1.591879
#       1984      0      9     0   2080        1     9      1  1.212543
#       1985      0     10     0   2080        1     9      0  1.765962
#       1986      0     11     0   2080        1     9      1  1.745894
#       1987      0     12     0   3380        1     9      1  1.466543
#
#             expersq  occupation
# nr    year
# 13    1980        1           9
#       1981        4           9
#       1982        9           9
#       1983       16           9
#       1984       25           5
# ...             ...         ...
# 12548 1983       64           5
#       1984       81           5
#       1985      100           5
#       1986      121           5
#       1987      144           5
#
# [4360 rows x 10 columns]

# %%
# Agregamos una columna adicional de año (opción 1):
wage_df['year'] = pd.Categorical( year )
wage_df.head()
# Out:
#          black  exper  hisp  hours  married  educ  union     lwage  expersq  \
# nr year
# 13 1980      0      1     0   2672        0    14      0  1.197540        1
#    1981      0      2     0   2320        0    14      1  1.853060        4
#    1982      0      3     0   2940        0    14      0  1.344462        9
#    1983      0      4     0   2960        0    14      0  1.433213       16
#    1984      0      5     0   3071        0    14      0  1.568125       25
#
#          occupation  year
# nr year
# 13 1980           9  1980
#    1981           9  1981
#    1982           9  1982
#    1983           9  1983
#    1984           5  1984

# %%
[ wage_df , pd.get_dummies(wage_df['year']) ]
# Out:
# [            black  exper  hisp  hours  married  educ  union     lwage  \
#  nr    year
#  13    1980      0      1     0   2672        0    14      0  1.197540
#        1981      0      2     0   2320        0    14      1  1.853060
#        1982      0      3     0   2940        0    14      0  1.344462
#        1983      0      4     0   2960        0    14      0  1.433213
#        1984      0      5     0   3071        0    14      0  1.568125
#  ...           ...    ...   ...    ...      ...   ...    ...       ...
#  12548 1983      0      8     0   2080        1     9      0  1.591879
#        1984      0      9     0   2080        1     9      1  1.212543
#        1985      0     10     0   2080        1     9      0  1.765962
#        1986      0     11     0   2080        1     9      1  1.745894
#        1987      0     12     0   3380        1     9      1  1.466543
#
#              expersq  occupation  year
#  nr    year
#  13    1980        1           9  1980
#        1981        4           9  1981
#        1982        9           9  1982
#        1983       16           9  1983
#        1984       25           5  1984
#  ...             ...         ...   ...
#  12548 1983       64           5  1983
#        1984       81           5  1984
#        1985      100           5  1985
#        1986      121           5  1986
#        1987      144           5  1987
#
#  [4360 rows x 11 columns],
#               1980   1981   1982   1983   1984   1985   1986   1987
#  nr    year
#  13    1980   True  False  False  False  False  False  False  False
#        1981  False   True  False  False  False  False  False  False
#        1982  False  False   True  False  False  False  False  False
#        1983  False  False  False   True  False  False  False  False
#        1984  False  False  False  False   True  False  False  False
#  ...           ...    ...    ...    ...    ...    ...    ...    ...
#  12548 1983  False  False  False   True  False  False  False  False
#        1984  False  False  False  False   True  False  False  False
#        1985  False  False  False  False  False   True  False  False
#        1986  False  False  False  False  False  False   True  False
#        1987  False  False  False  False  False  False  False   True
#
#  [4360 rows x 8 columns]]

# %%
# Agregamos columnas de dummies de Year (opción 2):
wage_df = pd.concat( [ wage_df , pd.get_dummies(wage_df['year']) ], axis=1)

# %%
# Show data:
wage_df
# Out:
#             black  exper  hisp  hours  married  educ  union     lwage  \
# nr    year
# 13    1980      0      1     0   2672        0    14      0  1.197540
#       1981      0      2     0   2320        0    14      1  1.853060
#       1982      0      3     0   2940        0    14      0  1.344462
#       1983      0      4     0   2960        0    14      0  1.433213
#       1984      0      5     0   3071        0    14      0  1.568125
# ...           ...    ...   ...    ...      ...   ...    ...       ...
# 12548 1983      0      8     0   2080        1     9      0  1.591879
#       1984      0      9     0   2080        1     9      1  1.212543
#       1985      0     10     0   2080        1     9      0  1.765962
#       1986      0     11     0   2080        1     9      1  1.745894
#       1987      0     12     0   3380        1     9      1  1.466543
#
#             expersq  occupation  ...   1986   1987   1980   1981   1982  \
# nr    year                       ...
# 13    1980        1           9  ...  False  False   True  False  False
#       1981        4           9  ...  False  False  False   True  False
#       1982        9           9  ...  False  False  False  False   True
#       1983       16           9  ...  False  False  False  False  False
#       1984       25           5  ...  False  False  False  False  False
# ...             ...         ...  ...    ...    ...    ...    ...    ...
# 12548 1983       64           5  ...  False  False  False  False  False
#       1984       81           5  ...  False  False  False  False  False
#       1985      100           5  ...  False  False  False  False  False
#       1986      121           5  ...   True  False  False  False  False
#       1987      144           5  ...  False   True  False  False  False
#
#              1983   1984   1985   1986   1987
# nr    year
# 13    1980  False  False  False  False  False
#       1981  False  False  False  False  False
#       1982  False  False  False  False  False
#       1983   True  False  False  False  False
#       1984  False   True  False  False  False
# ...           ...    ...    ...    ...    ...
# 12548 1983   True  False  False  False  False
#       1984  False   True  False  False  False
#       1985  False  False   True  False  False
#       1986  False  False  False   True  False
#       1987  False  False  False  False   True
#
# [4360 rows x 35 columns]

# %% [markdown]
# ## 3. Regresión Pooled

# %%
# Definición de variables exógeneas y endógena
X = [ 'black','hisp','exper','expersq','married', 'educ', 'union', 'year', 'hours' ]
X = sm.add_constant( wage_df[X] )
X
# Out:
#             const  black  hisp  exper  expersq  married  educ  union  year  \
# nr    year
# 13    1980    1.0      0     0      1        1        0    14      0  1980
#       1981    1.0      0     0      2        4        0    14      1  1981
#       1982    1.0      0     0      3        9        0    14      0  1982
#       1983    1.0      0     0      4       16        0    14      0  1983
#       1984    1.0      0     0      5       25        0    14      0  1984
# ...           ...    ...   ...    ...      ...      ...   ...    ...   ...
# 12548 1983    1.0      0     0      8       64        1     9      0  1983
#       1984    1.0      0     0      9       81        1     9      1  1984
#       1985    1.0      0     0     10      100        1     9      0  1985
#       1986    1.0      0     0     11      121        1     9      1  1986
#       1987    1.0      0     0     12      144        1     9      1  1987
#
#             hours
# nr    year
# 13    1980   2672
#       1981   2320
#       1982   2940
#       1983   2960
#       1984   3071
# ...           ...
# 12548 1983   2080
#       1984   2080
#       1985   2080
#       1986   2080
#       1987   3380
#
# [4360 rows x 10 columns]

# %%
# Definición de variables exógeneas y endógena
X1 = [ 'black','hisp','exper','expersq','married', 'educ', 'union', 1981, 1982,
       1983, 1984, 1985, 1986, 1987, 'hours' ]
X1 = sm.add_constant( wage_df[X1] )
X1
# Out:
#             const  black  hisp  exper  expersq  married  educ  union   1981  \
# nr    year
# 13    1980    1.0      0     0      1        1        0    14      0  False
#       1981    1.0      0     0      2        4        0    14      1   True
#       1982    1.0      0     0      3        9        0    14      0  False
#       1983    1.0      0     0      4       16        0    14      0  False
#       1984    1.0      0     0      5       25        0    14      0  False
# ...           ...    ...   ...    ...      ...      ...   ...    ...    ...
# 12548 1983    1.0      0     0      8       64        1     9      0  False
#       1984    1.0      0     0      9       81        1     9      1  False
#       1985    1.0      0     0     10      100        1     9      0  False
#       1986    1.0      0     0     11      121        1     9      1  False
#       1987    1.0      0     0     12      144        1     9      1  False
#
#              1981  ...   1985   1985   1985   1986   1986   1986   1987  \
# nr    year         ...
# 13    1980  False  ...  False  False  False  False  False  False  False
#       1981   True  ...  False  False  False  False  False  False  False
#       1982  False  ...  False  False  False  False  False  False  False
#       1983  False  ...  False  False  False  False  False  False  False
#       1984  False  ...  False  False  False  False  False  False  False
# ...           ...  ...    ...    ...    ...    ...    ...    ...    ...
# 12548 1983  False  ...  False  False  False  False  False  False  False
#       1984  False  ...  False  False  False  False  False  False  False
#       1985  False  ...   True   True   True  False  False  False  False
#       1986  False  ...  False  False  False   True   True   True  False
#       1987  False  ...  False  False  False  False  False  False   True
#
#              1987   1987  hours
# nr    year
# 13    1980  False  False   2672
#       1981  False  False   2320
#       1982  False  False   2940
#       1983  False  False   2960
#       1984  False  False   3071
# ...           ...    ...    ...
# 12548 1983  False  False   2080
#       1984  False  False   2080
#       1985  False  False   2080
#       1986  False  False   2080
#       1987   True   True   3380
#
# [4360 rows x 30 columns]

# %%
#
Y = wage_df[ 'lwage' ]
Y
# Out:
# nr     year
# 13     1980    1.197540
#        1981    1.853060
#        1982    1.344462
#        1983    1.433213
#        1984    1.568125
#                  ...
# 12548  1983    1.591879
#        1984    1.212543
#        1985    1.765962
#        1986    1.745894
#        1987    1.466543
# Name: lwage, Length: 4360, dtype: float64

# %%
# Regresión
model_1 = PooledOLS(Y, X1)
pooled_res_1 = model_1.fit()
print(pooled_res_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9f708898cd43> in <cell line: 0>()
#       1 # Regresión
# ----> 2 model_1 = PooledOLS(Y, X1)
#       3 pooled_res_1 = model_1.fit()
#       4 print(pooled_res_1)
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/model.py in __init__(self, dependent, exog, weights, check_rank)
#     919         check_rank: bool = True,
#     920     ) -> None:
# --> 921         super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#     922
#     923     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/model.py in __init__(self, dependent, exog, weights, check_rank)
#     318     ) -> None:
#     319         self.dependent = PanelData(dependent, "Dep")
# --> 320         self.exog = PanelData(exog, "Exog")
#     321         self._original_shape = self.dependent.shape
#     322         self._constant = False
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/data.py in __init__(self, x, var_name, convert_dummies, drop_first, copy)
#     248             raise TypeError("Only ndarrays, DataFrames or DataArrays are " "supported")
#     249         if convert_dummies:
# --> 250             self._frame = expand_categoricals(self._frame, drop_first)
#     251             self._frame = self._frame.astype(np.float64)
#     252
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/data.py in expand_categoricals(x, drop_first)
#     118 def expand_categoricals(x: pandas.DataFrame, drop_first: bool) -> DataFrame:
#     119     return concat(
# --> 120         [convert_columns(x[c], drop_first) for c in x.columns], axis=1, sort=False
#     121     )
#     122
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/data.py in <listcomp>(.0)
#     118 def expand_categoricals(x: pandas.DataFrame, drop_first: bool) -> DataFrame:
#     119     return concat(
# --> 120         [convert_columns(x[c], drop_first) for c in x.columns], axis=1, sort=False
#     121     )
#     122
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/data.py in convert_columns(s, drop_first)
#     105     s: pandas.Series, drop_first: bool
#     106 ) -> linearmodels.typing.data.AnyPandas:
# --> 107     if is_string_dtype(s.dtype) and s.map(lambda v: isinstance(v, str)).all():
#     108         s = s.astype("category")
#     109
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
# Regresión
model = PooledOLS(Y, X)
pooled_res = model.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  lwage   R-squared:                        0.1952
# Estimator:                  PooledOLS   R-squared (Between):              0.2034
# No. Observations:                4360   R-squared (Within):               0.1856
# Date:                Mon, Mar 10 2025   R-squared (Overall):              0.1952
# Time:                        14:41:13   Log-likelihood                   -2966.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      70.221
# Entities:                         545   P-value                           0.0000
# Avg Obs:                       8.0000   Distribution:                 F(15,4344)
# Min Obs:                       8.0000
# Max Obs:                       8.0000   F-statistic (robust):             70.221
#                                         P-value                           0.0000
# Time periods:                       8   Distribution:                 F(15,4344)
# Avg Obs:                       545.00
# Min Obs:                       545.00
# Max Obs:                       545.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.2073     0.0806     2.5714     0.0102      0.0493      0.3654
# black         -0.1379     0.0235    -5.8674     0.0000     -0.1839     -0.0918
# hisp           0.0210     0.0207     1.0135     0.3109     -0.0196      0.0617
# exper          0.0753     0.0137     5.4888     0.0000      0.0484      0.1022
# expersq       -0.0029     0.0008    -3.4778     0.0005     -0.0045     -0.0012
# married        0.1203     0.0158     7.6219     0.0000      0.0893      0.1512
# educ           0.0923     0.0052     17.678     0.0000      0.0821      0.1025
# union          0.1760     0.0171     10.269     0.0000      0.1424      0.2096
# year.1981      0.0604     0.0302     1.9978     0.0458      0.0011      0.1197
# year.1982      0.0635     0.0331     1.9187     0.0551     -0.0014      0.1284
# year.1983      0.0661     0.0365     1.8080     0.0707     -0.0056      0.1377
# year.1984      0.0956     0.0400     2.3922     0.0168      0.0173      0.1739
# year.1985      0.1138     0.0432     2.6328     0.0085      0.0290      0.1985
# year.1986      0.1477     0.0463     3.1921     0.0014      0.0570      0.2384
# year.1987      0.1832     0.0493     3.7160     0.0002      0.0865      0.2798
# hours       -7.55e-05   1.34e-05    -5.6326     0.0000     -0.0001  -4.922e-05
# ==============================================================================

# %% [markdown]
# ## 4. Efectos aleatorios

# %%
# Regresión
model = RandomEffects(Y, X)
re_res = model.fit()
print(re_res)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                  lwage   R-squared:                        0.1976
# Estimator:              RandomEffects   R-squared (Between):              0.1716
# No. Observations:                4360   R-squared (Within):               0.2013
# Date:                Mon, Mar 10 2025   R-squared (Overall):              0.1854
# Time:                        14:41:33   Log-likelihood                   -1569.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      71.315
# Entities:                         545   P-value                           0.0000
# Avg Obs:                       8.0000   Distribution:                 F(15,4344)
# Min Obs:                       8.0000
# Max Obs:                       8.0000   F-statistic (robust):             71.315
#                                         P-value                           0.0000
# Time periods:                       8   Distribution:                 F(15,4344)
# Avg Obs:                       545.00
# Min Obs:                       545.00
# Max Obs:                       545.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1989     0.1528     1.3022     0.1929     -0.1006      0.4985
# black         -0.1408     0.0481    -2.9306     0.0034     -0.2350     -0.0466
# hisp           0.0296     0.0429     0.6902     0.4901     -0.0545      0.1138
# exper          0.1227     0.0154     7.9474     0.0000      0.0924      0.1529
# expersq       -0.0056     0.0007    -8.2043     0.0000     -0.0070     -0.0043
# married        0.0691     0.0166     4.1579     0.0000      0.0365      0.1017
# educ           0.0937     0.0107     8.7315     0.0000      0.0727      0.1148
# union          0.0978     0.0177     5.5248     0.0000      0.0631      0.1324
# year.1981      0.0429     0.0245     1.7519     0.0799     -0.0051      0.0909
# year.1982      0.0301     0.0322     0.9323     0.3512     -0.0331      0.0933
# year.1983      0.0244     0.0416     0.5877     0.5567     -0.0571      0.1060
# year.1984      0.0485     0.0514     0.9437     0.3454     -0.0523      0.1494
# year.1985      0.0621     0.0615     1.0097     0.3127     -0.0584      0.1825
# year.1986      0.0983     0.0716     1.3735     0.1697     -0.0420      0.2386
# year.1987      0.1475     0.0818     1.8037     0.0714     -0.0128      0.3078
# hours         -0.0001  1.269e-05    -9.5935     0.0000     -0.0001  -9.688e-05
# ==============================================================================

# %%
# Descomposición de varianza
re_res.variance_decomposition
# Out:
# Effects                   0.107522
# Residual                  0.120095
# Percent due to Effects    0.472383
# Name: Variance Decomposition, dtype: float64

# %% [markdown]
# ## 5. Efectos fijos

# %%
# Regresion
#(Estas líneas generan un error que es intencional..)
model = PanelOLS(Y, X, entity_effects = True)
fe_res = model.fit()
print(fe_res)
# Out:
# ---------------------------------------------------------------------------
# AbsorbingEffectError                      Traceback (most recent call last)
# <ipython-input-18-a990ea67f568> in <cell line: 0>()
#       2 #(Estas líneas generan un error que es intencional..)
#       3 model = PanelOLS(Y, X, entity_effects = True)
# ----> 4 fe_res = model.fit()
#       5 print(fe_res)
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/model.py in fit(self, use_lsdv, use_lsmr, low_memory, cov_type, debiased, auto_df, count_effects, **cov_config)
#    1941         if self.entity_effects or self.time_effects or self.other_effects:
#    1942             if not self._drop_absorbed:
# -> 1943                 check_absorbed(x, [str(var) for var in self.exog.vars])
#    1944             else:
#    1945                 # TODO: Need to special case the constant here when determining which
#
# /usr/local/lib/python3.11/dist-packages/linearmodels/panel/utility.py in check_absorbed(x, variables, x_orig)
#     457         absorbed_variables = "\n".join(rows)
#     458         msg = absorbing_error_msg.format(absorbed_variables=absorbed_variables)
# --> 459         raise AbsorbingEffectError(msg)
#     460     if x_orig is None:
#     461         return
#
# AbsorbingEffectError:
# The model cannot be estimated. The included effects have fully absorbed
# one or more of the variables. This occurs when one or more of the dependent
# variable is perfectly explained using the effects included in the model.
#
# The following variables or variable combinations have been fully absorbed
# or have become perfectly collinear after effects are removed:
#
#           const, black, hisp, exper, educ, union, year.1981, year.1982, year.1983, year.1984, year.1985, year.1986, year.1987
#           const, black, hisp, exper, married, educ, union, year.1981, year.1982, year.1983, year.1984, year.1985, year.1986, year.1987
#           const, black, hisp, exper, expersq, married, educ, union, year.1981, year.1982, year.1983, year.1984, year.1985, year.1986, year.1987, hours
#           const, black, hisp, exper, expersq, married, educ, union, year.1981, year.1982, year.1983, year.1984, year.1985, year.1986, year.1987, hours
#
# Set drop_absorbed=True to automatically drop absorbed variables.

# %%
# Regresion con efectos fijos por entidad
# Omitimos: 'exper', 'black','hisp', 'educ'
X = [ 'expersq', 'union', 'married', 'year', 'hours' ]
X = sm.add_constant(wage_df[X])
model = PanelOLS(Y, X, entity_effects = True)
fe_res = model.fit()
print(fe_res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  lwage   R-squared:                        0.2022
# Estimator:                   PanelOLS   R-squared (Between):             -0.0726
# No. Observations:                4360   R-squared (Within):               0.2022
# Date:                Mon, Mar 10 2025   R-squared (Overall):              0.0546
# Time:                        14:43:21   Log-likelihood                   -1266.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      87.669
# Entities:                         545   P-value                           0.0000
# Avg Obs:                       8.0000   Distribution:                 F(11,3804)
# Min Obs:                       8.0000
# Max Obs:                       8.0000   F-statistic (robust):             87.669
#                                         P-value                           0.0000
# Time periods:                       8   Distribution:                 F(11,3804)
# Avg Obs:                       545.00
# Min Obs:                       545.00
# Max Obs:                       545.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1.7047     0.0329     51.891     0.0000      1.6403      1.7691
# expersq       -0.0062     0.0007    -8.8773     0.0000     -0.0076     -0.0049
# union          0.0727     0.0191     3.8110     0.0001      0.0353      0.1101
# married        0.0476     0.0181     2.6356     0.0084      0.0122      0.0831
# year.1981      0.1735     0.0218     7.9673     0.0000      0.1308      0.2161
# year.1982      0.2910     0.0244     11.933     0.0000      0.2432      0.3388
# year.1983      0.4177     0.0295     14.150     0.0000      0.3598      0.4756
# year.1984      0.5743     0.0367     15.650     0.0000      0.5023      0.6462
# year.1985      0.7199     0.0458     15.728     0.0000      0.6301      0.8096
# year.1986      0.8898     0.0567     15.687     0.0000      0.7786      1.0010
# year.1987      1.0757     0.0695     15.486     0.0000      0.9396      1.2119
# hours         -0.0001  1.335e-05    -10.164     0.0000     -0.0002     -0.0001
# ==============================================================================
#
# F-test for Poolability: 9.5083
# P-value: 0.0000
# Distribution: F(544,3804)
#
# Included effects: Entity

# %%
# Regresion con efectos fijos por entidad y tiempo
# Omitimos: 'exper', 'black','hisp', 'educ', 'year'
X = ['expersq', 'union', 'married', 'hours']
X = sm.add_constant(wage_df[X])
model = PanelOLS(Y, X, entity_effects = True, time_effects = True)
fe_te_res = model.fit()
print(fe_te_res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  lwage   R-squared:                        0.0474
# Estimator:                   PanelOLS   R-squared (Between):             -0.0726
# No. Observations:                4360   R-squared (Within):              -0.6951
# Date:                Mon, Mar 10 2025   R-squared (Overall):             -0.3606
# Time:                        14:43:53   Log-likelihood                   -1266.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      47.359
# Entities:                         545   P-value                           0.0000
# Avg Obs:                       8.0000   Distribution:                  F(4,3804)
# Min Obs:                       8.0000
# Max Obs:                       8.0000   F-statistic (robust):             47.359
#                                         P-value                           0.0000
# Time periods:                       8   Distribution:                  F(4,3804)
# Avg Obs:                       545.00
# Min Obs:                       545.00
# Max Obs:                       545.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          2.2224     0.0509     43.647     0.0000      2.1226      2.3222
# expersq       -0.0062     0.0007    -8.8773     0.0000     -0.0076     -0.0049
# union          0.0727     0.0191     3.8110     0.0001      0.0353      0.1101
# married        0.0476     0.0181     2.6356     0.0084      0.0122      0.0831
# hours         -0.0001  1.335e-05    -10.164     0.0000     -0.0002     -0.0001
# ==============================================================================
#
# F-test for Poolability: 10.503
# P-value: 0.0000
# Distribution: F(551,3804)
#
# Included effects: Entity, Time

# %% [markdown]
# ## 6. Comparación de modelos

# %%
#
print(compare( { 'Fix efect Ent.': fe_res,
                 'Fix Efect Ent-Time': fe_te_res,
                 'Radom efects': re_res,
                 'Pooled': pooled_res } ))
# Out:
#                                      Model Comparison
# ==========================================================================================
#                         Fix efect Ent. Fix Efect Ent-Time      Radom efects         Pooled
# ------------------------------------------------------------------------------------------
# Dep. Variable                    lwage              lwage             lwage          lwage
# Estimator                     PanelOLS           PanelOLS     RandomEffects      PooledOLS
# No. Observations                  4360               4360              4360           4360
# Cov. Est.                   Unadjusted         Unadjusted        Unadjusted     Unadjusted
# R-squared                       0.2022             0.0474            0.1976         0.1952
# R-Squared (Within)              0.2022            -0.6951            0.2013         0.1856
# R-Squared (Between)            -0.0726            -0.0726            0.1716         0.2034
# R-Squared (Overall)             0.0546            -0.3606            0.1854         0.1952
# F-statistic                     87.669             47.359            71.315         70.221
# P-value (F-stat)                0.0000             0.0000            0.0000         0.0000
# =====================     ============       ============   ===============   ============
# const                           1.7047             2.2224            0.1989         0.2073
#                               (51.891)           (43.647)          (1.3022)       (2.5714)
# expersq                        -0.0062            -0.0062           -0.0056        -0.0029
#                              (-8.8773)          (-8.8773)         (-8.2043)      (-3.4778)
# union                           0.0727             0.0727            0.0978         0.1760
#                               (3.8110)           (3.8110)          (5.5248)       (10.269)
# married                         0.0476             0.0476            0.0691         0.1203
#                               (2.6356)           (2.6356)          (4.1579)       (7.6219)
# year.1981                       0.1735                               0.0429         0.0604
#                               (7.9673)                             (1.7519)       (1.9978)
# year.1982                       0.2910                               0.0301         0.0635
#                               (11.933)                             (0.9323)       (1.9187)
# year.1983                       0.4177                               0.0244         0.0661
#                               (14.150)                             (0.5877)       (1.8080)
# year.1984                       0.5743                               0.0485         0.0956
#                               (15.650)                             (0.9437)       (2.3922)
# year.1985                       0.7199                               0.0621         0.1138
#                               (15.728)                             (1.0097)       (2.6328)
# year.1986                       0.8898                               0.0983         0.1477
#                               (15.687)                             (1.3735)       (3.1921)
# year.1987                       1.0757                               0.1475         0.1832
#                               (15.486)                             (1.8037)       (3.7160)
# hours                          -0.0001            -0.0001           -0.0001      -7.55e-05
#                              (-10.164)          (-10.164)         (-9.5935)      (-5.6326)
# black                                                               -0.1408        -0.1379
#                                                                   (-2.9306)      (-5.8674)
# hisp                                                                 0.0296         0.0210
#                                                                    (0.6902)       (1.0135)
# exper                                                                0.1227         0.0753
#                                                                    (7.9474)       (5.4888)
# educ                                                                 0.0937         0.0923
#                                                                    (8.7315)       (17.678)
# ======================= ==============     ============== ================= ==============
# Effects                         Entity             Entity
#                                                      Time
# ------------------------------------------------------------------------------------------
#
# T-stats reported in parentheses

# %% [markdown]
# ## 7. Varianza Robusta:

# %%
# Rregresión
X = ['expersq', 'union', 'married', 'year', 'hours']
X = sm.add_constant(wage_df[X])
model = PanelOLS(Y, X, entity_effects = True)
#fe_res = model.fit(cov_type = 'robust')
# NOTAS: “unadjusted”, “homoskedastic” - Assume residual are homoskedastic, AND
#       “robust”, “heteroskedastic” - Control for heteroskedasticity using White’s estimator
fe_res = model.fit(cov_type = "clustered", cluster_entity = True)
# NOTAS: clust_entity_time = mod.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)

print(fe_res)
